# %%
import pandas as pd
import scipy

# %%
results = pd.read_csv('results.csv')

# %%
results[['no_features', 'features', 'voting', 'bagging']]
# Out:
#     no_features  features    voting   bagging
# 0      0.794913  0.791788  0.810593  0.770062
# 1      0.199684  0.193717  0.258227  0.224985
# 2      0.982329  0.990345  0.918234  0.803078
# 3      0.546500  0.533742  0.598483  0.580281
# 4      0.872028  0.872010  0.880564  0.854149
# 5      0.951939  0.958200  0.844390  0.954034
# 6      0.976667  0.978095  0.964286  0.968095
# 7      0.878889  0.888889  0.890909  0.910000
# 8      0.706670  0.699800  0.708781  0.715651
# 9      0.712436  0.713321  0.710690  0.682024
# 10     0.770213  0.787234  0.848936  0.825532
# 11     0.958822  0.956549  0.961150  0.951681
# 12     0.831906  0.830415  0.850770  0.869506
# 13     0.813180  0.819531  0.867295  0.830217
# 14     0.917488  0.923291  0.894939  0.926228
# 15     0.721293  0.726491  0.712011  0.748552
# 16     0.700571  0.681216  0.719395  0.703280
# 17     0.968901  0.969452  0.962750  0.933946
# 18     0.303763  0.296484  0.315087  0.339908
# ...

# %%
results
# Out:
#                    Unnamed: 0  no_features  features    voting   bagging  \
# 0           load_mammographic     0.794913  0.791788  0.810593  0.770062
# 1                load_abalone     0.199684  0.193717  0.258227  0.224985
# 2                load_balance     0.982329  0.990345  0.918234  0.803078
# 3                  load_yeast     0.546500  0.533742  0.598483  0.580281
# 4                 load_biodeg     0.872028  0.872010  0.880564  0.854149
# 5                load_tic_tac     0.951939  0.958200  0.844390  0.954034
# 6           load_segmentation     0.976667  0.978095  0.964286  0.968095
# 7      load_phishing_websites     0.878889  0.888889  0.890909  0.910000
# 8           load_indian_liver     0.706670  0.699800  0.708781  0.715651
# 9   load_diabetic_retinppathy     0.712436  0.713321  0.710690  0.682024
# 10      load_thoracic_surgery     0.770213  0.787234  0.848936  0.825532
# 11        load_house_votes_84     0.958822  0.956549  0.961150  0.951681
# ...
